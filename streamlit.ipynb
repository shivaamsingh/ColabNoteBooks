# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 98.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 105.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py
import streamlit as st

st.title("Hello from Colab!")
st.write("This Streamlit app is running in Google Colab via ngrok.")
# Out:
# Writing app.py

# %%
# !pip install streamlit pyngrok

# Write app
# %%writefile app.py
import streamlit as st
st.title("Streamlit in Colab!")
st.write("Running via ngrok")

# Set authtoken
from pyngrok import ngrok
ngrok.set_auth_token("2zh90tpfHmsjPKAl4ojyKWyp79a_7w5EajsXoRqGjnpTWmjVe")

# Connect to port 8501
public_url = ngrok.connect(8501)
print(public_url)

# Run streamlit app
# !streamlit run app.py &> /dev/null &
# Out:
# ...
# UsageError: Line magic function `%%writefile` not found.
